# %%
import numpy as np
import epilib as ep
import matplotlib.pyplot as plt
import json
import seaborn as sns

from importlib import reload  

ep = reload(ep)

# %%
class Sim:
    
    def __init__(self, path):
        self.hic = ep.get_contactmap(path+"/contacts.txt")
        self.d = ep.get_diagonal(self.hic)

# %%
off = Sim("off")
on = Sim("times2")

off_long = Sim("off.long")
on_long = Sim("on.long")

kaelin = Sim("kaelin")

# %%
ep.plot_contactmap(on.hic, 0.01)

# %%
ep.plot_contactmap(off_long.hic, 0.01)

# %%
ep.plot_contactmap(on.hic, 0.01)

# %%
ep.plot_contactmap(on_long.hic, 0.01)

# %%
print(np.mean(on_long.hic))
print(np.std(on_long.hic))
# Out:
# 0.00761752345133293
# 0.03497514608471113

# %%
print(np.mean(off_long.hic))
print(np.std(off_long.hic))
# Out:
# 0.00789499956522944
# 0.03490670775209126

# %%
plt.plot(on.d[10:])
#plt.plot(off.d[10:])
plt.plot(on_long.d[10:])

# %%
plt.figure(figsize=(12,10))
sns.heatmap(on_long.hic-off_long.hic, vmin = -0.01, vmax = 0.01, cmap = "bwr")

# %%
def get_smatrix():
    with open("config.json") as f:
        config = json.load(f)

        nspecies = config['nspecies']

        letters = 'ABCDE'

        chi = np.zeros((nspecies, nspecies))
        for i in range(nspecies):
            for j in range(nspecies):
                if j >= i:
                    chi[i,j] = config["chi" + letters[i] + letters[j]]
                    chi[j,i] = config["chi" + letters[i] + letters[j]]

        seqs = []
        for file in config["chipseq_files"]:
            seqs.append( np.loadtxt(file) )
        seqs = np.array(seqs)
    

    smatrix = seqs.T @ chi @ seqs
    
    return smatrix

# %%
smatrix = get_smatrix()

# %%
sns.heatmap(smatrix)

# %%
np.savetxt("smatrix.txt", smatrix, fmt="%d")
